# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\12242\\103122\\NBA-Fantasy-Point-Projections\\data\\Prepared_Data.csv')

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# creating the dataset
data = {'My Model': 4.0, 'DraftKings':5.5}
Models = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (8, 6))

# creating the bar plot

plt.bar(Models, values, color ='maroon', width = 0.5)
        
plt.xlabel("Prediction Models")
plt.ylabel("Mean Squared Error")
plt.title("Error Metric Comparison")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
